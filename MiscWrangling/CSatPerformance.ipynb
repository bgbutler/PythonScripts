# %%
# standard libraries
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import os
import re

# plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# get the datetime library for date & time calcs
from datetime import datetime, timedelta

# %%
# get the performance data

# load the the main data sets
branchData = os.path.normpath("C:/Users/n846490/Documents/DataScience/CSVs/BranchPLDataYTD2016.csv")
plData = pd.read_csv(branchData)

# %%
plData.head()
# Out:
#                    Region                District             Branch  \
# 0   Southern - Western NE  Greater Hartford North     South Windsor
# 1  Metro NY - Northern NJ    Queens - Long Island        Bay Terrace
# 2  Metro NY - Northern NJ                Brooklyn      Newkirk Plaza
# 3  Metro NY - Northern NJ                Brooklyn            Redhook
# 4   Southern - Western NE  Greater Hartford North  Farmington Avenue
#
#    Branch Number District Peer Group Branch Peer Group  Peer Rank  \
# 0            513                   2                 6        138
# 1           2105                   3                 6        142
# 2           2103                   3                 6        136
# 3           2121                   3                 2         40
# 4            521                   2                 6        141
#
#   Performance Level  CSAT Score
# 0                 1        0.57
# 1                 1        0.74
# 2                 1        0.66
# ...

# %%
plData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 9 columns):
# Region                 763 non-null object
# District               763 non-null object
# Branch                 763 non-null object
# Branch Number          763 non-null int64
# District Peer Group    763 non-null object
# Branch Peer Group      763 non-null object
# Peer Rank              763 non-null int64
# Performance Level      763 non-null object
# CSAT Score             763 non-null float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 53.7+ KB

# %%
# now drop the null in place

plData = plData[plData['Performance Level'] != 'n/a']

# %%
# change the data typr of Performance Level

plData['Performance Level'] = plData['Performance Level'].astype(int)

# %%
# plot the relationship

sns.set(font_scale=1.5)

plt.figure(figsize=(15,6))

sns.stripplot(x='Performance Level', y='CSAT Score', data=plData, jitter = True)

plt.ylim(0,1.1)
# Out:
# (0, 1.1)

# %%
sns.set(font_scale=1.5)

plt.figure(figsize=(15,6))

sns.violinplot(x='Performance Level', y='CSAT Score', data=plData, jitter = True)

plt.ylim(0,1.1)
# Out:
# (0, 1.1)

# %%
plData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 670 entries, 0 to 761
# Data columns (total 9 columns):
# Region                 670 non-null object
# District               670 non-null object
# Branch                 670 non-null object
# Branch Number          670 non-null int64
# District Peer Group    670 non-null object
# Branch Peer Group      670 non-null object
# Peer Rank              670 non-null int64
# Performance Level      670 non-null int32
# CSAT Score             670 non-null float64
# dtypes: float64(1), int32(1), int64(2), object(5)
# memory usage: 49.7+ KB

# %%
plt.figure(figsize=(15,6))

sns.jointplot(x='Performance Level', y='CSAT Score', kind = 'kde', data=plData)
# Out:
# C:\Users\n846490\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
