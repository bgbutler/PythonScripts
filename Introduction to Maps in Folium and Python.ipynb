# %%
import folium
import pandas as pd

# %%
df_suburbs = pd.read_excel(r'C:\Users\ebisys\Documents\water_consumption_suburbs.xlsx', index_col=0, sheet_name='Sheet1')
df_suburbs.head(10)
# Out:
#             Suburb  Number of single-residential properties_number  \
# 0          ATHLONE                                            2272
# 1           AURORA                                             426
# 2       BANTRY BAY                                             248
# 3  BELLVILLE SOUTH                                            2041
# 4        BERGVLIET                                            1488
# 5     BISHOP LAVIS                                            3746
# 6     BISHOPSCOURT                                             538
# 7         BLOMTUIN                                             201
# 8      BONTEHEUWEL                                            7098
# 9         BOTHASIG                                            3399
#
#    Oct 2017\nkl/month    Month  Year   Latitude  Longitude
# 0                  11  October  2017 -33.967220  18.502140
# 1                  10  October  2017 -32.705958  18.485135
# 2                  13  October  2017 -33.927953  18.382592
# 3                  11  October  2017 -33.920011  18.642819
# 4                   8  October  2017 -34.047464  18.452499
# 5                   9  October  2017 -33.947283  18.575133
# 6                  12  October  2017 -33.991092  18.444217
# 7                   9  October  2017 -33.882677  18.652075
# 8                   9  October  2017 -33.950161  18.554446
# 9                   9  October  2017 -33.860418  18.544612

# %%
df_suburbs.columns
# Out:
# Index(['Suburb', 'Number of single-residential properties_number',
#        'Oct 2017\nkl/month', 'Month', 'Year', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_suburbs.shape
# Out:
# (121, 7)

# %%
df_suburbs.describe()
# Out:
#        Number of single-residential properties_number  Oct 2017\nkl/month  \
# count                                      121.000000          121.000000
# mean                                      1849.983471            8.413223
# std                                       2506.756526            3.275336
# min                                          0.000000            0.000000
# 25%                                        364.000000            8.000000
# 50%                                       1009.000000            9.000000
# 75%                                       2411.000000           10.000000
# max                                      20719.000000           13.000000
#
#          Year    Latitude   Longitude
# count   121.0  121.000000  121.000000
# mean   2017.0  -33.944923   18.668673
# std       0.0    0.217793    0.568946
# min    2017.0  -34.589721   18.329108
# 25%    2017.0  -34.037828   18.457490
# 50%    2017.0  -33.950865   18.505041
# 75%    2017.0  -33.908311   18.638249
# max    2017.0  -32.705958   22.192635

# %%
map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_649cb6cbfaa840b0753f324f1de188ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_649cb6cbfaa840b0753f324f1de188ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_649cb6cbfaa840b0753f324f1de188ee = L.map(
#                 &quot;map_649cb6cbfaa840b0753f324f1de188ee&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3b266492ac3a8fd6b65e0ed0539b0c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c3b266492ac3a8fd6b65e0ed0539b0c0.addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f420d5e98e83b3ddd5c69842b3891c49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f420d5e98e83b3ddd5c69842b3891c49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f420d5e98e83b3ddd5c69842b3891c49 = L.map(
#                 &quot;map_f420d5e98e83b3ddd5c69842b3891c49&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01cf31eec0a239886d5b91e963abd5cb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01cf31eec0a239886d5b91e963abd5cb.addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_suburbs_location = df_suburbs[['Latitude', 'Longitude']]
#df_suburbs_location
suburbs_location_list = df_suburbs_location.values.tolist()
suburbs_location_list_size = len(suburbs_location_list)
suburbs_location_list_size
# Out:
# 121

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point]).add_to(map_dark)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_649cb6cbfaa840b0753f324f1de188ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_649cb6cbfaa840b0753f324f1de188ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_649cb6cbfaa840b0753f324f1de188ee = L.map(
#                 &quot;map_649cb6cbfaa840b0753f324f1de188ee&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3b266492ac3a8fd6b65e0ed0539b0c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c3b266492ac3a8fd6b65e0ed0539b0c0.addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             tile_layer_c3b266492ac3a8fd6b65e0ed0539b0c0.addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_108160dc4fefde028243f22ef80cc45e = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_7c5f174bdd05dc83bd2b9263861d8ce2 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_49b79cfbac9dceaaa7ceb9d7667ab2d4 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_788605a5c1d1b281fe713b246908fac3 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_7110a15258faa741be7d8f8b65702532 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_ecbdb301bd7a6f1ac305daf29e440359 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_34e879d9e0b08572ae0199c533f5d599 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_f23164668d65d04c36dad5c9374adc77 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_99ee13010caea1b715811859f38ed4a7 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_58261899545676141c82f14c27c70925 = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_2b31e03d676085566a19c3fbf242aa73 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_4c316498e13ba107dfc832eb76bfad59 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_d8e82adb06a7620d4f0d1147811dfc82 = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_3d9c71763f23c338c92135bdd5e76a14 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_a5df4407e4018a3ea2b3fb1c279bacea = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_0c786309173f2c3dcc6fa78ec58bd668 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_f809cf16c4342c2e087fecb17e7cab0b = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_f9046b2f6b6cc20d7ba0f00c76073e33 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_d9b62f32cbb0089cf6a41c5aea21c724 = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_72d49a0274a4c69df1961d1c623540f5 = L.marker(
#                 [-33.994451, 18.595982],
#                 {}
#             ).addTo(map_649cb6cbfaa840b0753f324f1de188ee);
#
#
#             var marker_24d

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f420d5e98e83b3ddd5c69842b3891c49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f420d5e98e83b3ddd5c69842b3891c49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f420d5e98e83b3ddd5c69842b3891c49 = L.map(
#                 &quot;map_f420d5e98e83b3ddd5c69842b3891c49&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01cf31eec0a239886d5b91e963abd5cb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01cf31eec0a239886d5b91e963abd5cb.addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             tile_layer_01cf31eec0a239886d5b91e963abd5cb.addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_411474937667e91a995d841ac0fc3dd9 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_cdbe757583e3a5ccfa70ae2950c706c0 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_28b252882a2a60dc48e7c4c6949f61d4 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_147da14dd629c28d1dbc878ad293532a = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_3305ccde1312576919bc644611282d3a = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_9805afab28b958bdc682ffbbd6e83de3 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_fd05a3eb0d0496f7dbc1e6c94da74233 = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_23a04c8161877454fb89f468917a6495 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_4db0e5fa33ddd6117c3bdf3996c7e4a5 = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_431fa7f689af4b55e49bccddc40e902d = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_44e94b6b2560f55ee129b29e9fe532b5 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_d13adbc5c1f9d17549905e444c6ac927 = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_55437932d28145a5faa1e6a92896faad = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_349bb6155936b1b4f846895477a8bf96 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_7c08b119c7dc33845741b6e3311a61dc = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_1266e4f38a4247e9dfe77c1823aa2601 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_57cc655f5cd2b7aaa09d6977871c4edd = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_05bb7fc9203af79eba55d5369b9b8123 = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_8bb10936cd85f3458fdae114784842af = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_f420d5e98e83b3ddd5c69842b3891c49);
#
#
#             var marker_bb023334da693280d54f776a20aed52f = L.marker(
#                 [-33.994451, 18.595982],

# %%
def map_initialization():
    map_osm = folium.Map(location=[-33.925, 18.625], zoom_start=10)
    map_dark = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)
    return map_osm, map_dark

# %%
map_osm, map_dark = map_initialization()

for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_osm)
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point]).add_to(map_dark)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ab79c64e3e1373bac8b3fba46e1453f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ab79c64e3e1373bac8b3fba46e1453f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ab79c64e3e1373bac8b3fba46e1453f = L.map(
#                 &quot;map_3ab79c64e3e1373bac8b3fba46e1453f&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aee50f5e7a0c6d9a6fffb6eb243121df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aee50f5e7a0c6d9a6fffb6eb243121df.addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#             var marker_5eebf9a8bcc967f5093ab48d924cff52 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#         var popup_fa90e7686a415bbfbc408bcef9e0a8a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a699448d53631314488eaf957325e4a5 = $(`&lt;div id=&quot;html_a699448d53631314488eaf957325e4a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_fa90e7686a415bbfbc408bcef9e0a8a9.setContent(html_a699448d53631314488eaf957325e4a5);
#
#
#
#         marker_5eebf9a8bcc967f5093ab48d924cff52.bindPopup(popup_fa90e7686a415bbfbc408bcef9e0a8a9)
#         ;
#
#
#
#
#             var marker_55d755594ac2bfd74823aae5c883fd22 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#         var popup_a05dbffcdabf092be0e04c11788ce706 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_526c159a07742b2f0516490d826f11de = $(`&lt;div id=&quot;html_526c159a07742b2f0516490d826f11de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_a05dbffcdabf092be0e04c11788ce706.setContent(html_526c159a07742b2f0516490d826f11de);
#
#
#
#         marker_55d755594ac2bfd74823aae5c883fd22.bindPopup(popup_a05dbffcdabf092be0e04c11788ce706)
#         ;
#
#
#
#
#             var marker_d0bf7307028d37befe85316cddec7f8b = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#         var popup_b5727f35862972d1dfe1731662cf2200 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2153b9b64e903431969e5cdd25c611fa = $(`&lt;div id=&quot;html_2153b9b64e903431969e5cdd25c611fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_b5727f35862972d1dfe1731662cf2200.setContent(html_2153b9b64e903431969e5cdd25c611fa);
#
#
#
#         marker_d0bf7307028d37befe85316cddec7f8b.bindPopup(popup_b5727f35862972d1dfe1731662cf2200)
#         ;
#
#
#
#
#             var marker_c8b47773b58fda02dafa89059305a3b9 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#         var popup_13cc59554d0bee5503c61134be7253c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0c85866ab7e5f2aac65473b7af8a7ec = $(`&lt;div id=&quot;html_f0c85866ab7e5f2aac65473b7af8a7ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BELLVILLE SOUTH&lt;/div&gt;`)[0];
#                 popup_13cc59554d0bee5503c61134be7253c5.setContent(html_f0c85866ab7e5f2aac65473b7af8a7ec);
#
#
#
#         marker_c8b47773b58fda02dafa89059305a3b9.bindPopup(popup_13cc59554d0bee5503c61134be7253c5)
#         ;
#
#
#
#
#             var marker_2ea1a65fe4430c46c0016ed15b0838e8 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);
#
#
#         var popup_a23d534a6751f510bd2309643d072816 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2180a69b311a64f651b973976a1803f = $(`&lt;div id=&quot;html_b2180a69b311a64f651b973976a1803f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BERGVLIET&lt;/div&gt;`)[0];
#                 popup_a23d534a6751f510bd2309643d072816.setContent(html_b2180a69b311a64f651b973976a1803f);
#
#
#
#         marker_2ea1a65fe4430c46c0016ed15b0838e8.bindPopup(popup_a23d534a6751f510bd2309643d072816)
#         ;
#
#
#
#
#             var marker_077f999f6ddda17ae773dd3ad515a817 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_3ab79c64e3e1373bac8b3fba46e1453f);

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8693ac98183c3731a0b5debe0c25a38a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8693ac98183c3731a0b5debe0c25a38a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8693ac98183c3731a0b5debe0c25a38a = L.map(
#                 &quot;map_8693ac98183c3731a0b5debe0c25a38a&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5726fe5a2233a2ca6b57f2db3a515293 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5726fe5a2233a2ca6b57f2db3a515293.addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#             var marker_5c7068709908c5bf1f7e4577203434fe = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#         var popup_1a75a59a4ebc36ac4127c7deced44b8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1a816f95766fadd6f7137548856cba1 = $(`&lt;div id=&quot;html_f1a816f95766fadd6f7137548856cba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_1a75a59a4ebc36ac4127c7deced44b8e.setContent(html_f1a816f95766fadd6f7137548856cba1);
#
#
#
#         marker_5c7068709908c5bf1f7e4577203434fe.bindPopup(popup_1a75a59a4ebc36ac4127c7deced44b8e)
#         ;
#
#
#
#
#             var marker_2bc08bbc8e62c7f5578bca122c06070f = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#         var popup_f45414d6fbb5a7b09f84c5de9d37563f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e04d400432687497289f636925fcca42 = $(`&lt;div id=&quot;html_e04d400432687497289f636925fcca42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_f45414d6fbb5a7b09f84c5de9d37563f.setContent(html_e04d400432687497289f636925fcca42);
#
#
#
#         marker_2bc08bbc8e62c7f5578bca122c06070f.bindPopup(popup_f45414d6fbb5a7b09f84c5de9d37563f)
#         ;
#
#
#
#
#             var marker_9a765f0f9597d8d1bd88d0220fe64450 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#         var popup_f71a0956e2e9984c92026abce71fdebc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50ed8ead1829c958f858fd37a5b00bcb = $(`&lt;div id=&quot;html_50ed8ead1829c958f858fd37a5b00bcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_f71a0956e2e9984c92026abce71fdebc.setContent(html_50ed8ead1829c958f858fd37a5b00bcb);
#
#
#
#         marker_9a765f0f9597d8d1bd88d0220fe64450.bindPopup(popup_f71a0956e2e9984c92026abce71fdebc)
#         ;
#
#
#
#
#             var marker_f5d13884fdbf8021d30285f279eacb3f = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#         var popup_94e239f0000fcbcbd97df1f7b94812a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e27a961bf71e3714cc441f77e3b13634 = $(`&lt;div id=&quot;html_e27a961bf71e3714cc441f77e3b13634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BELLVILLE SOUTH&lt;/div&gt;`)[0];
#                 popup_94e239f0000fcbcbd97df1f7b94812a7.setContent(html_e27a961bf71e3714cc441f77e3b13634);
#
#
#
#         marker_f5d13884fdbf8021d30285f279eacb3f.bindPopup(popup_94e239f0000fcbcbd97df1f7b94812a7)
#         ;
#
#
#
#
#             var marker_60a1943d760f9599d7fa4404b732177f = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_8693ac98183c3731a0b5debe0c25a38a);
#
#
#         var popup_d688c92832a8e48563270f7794960fba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4f6a1c46ee4ab8ab3f6f1af2f9bdb82 = $(`&lt;div id=&quot;html_d4f6a1c46ee4ab8ab3f6f1af2f9bdb82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BERGVLIET&lt;/div&gt;`)[0];
#                 popup_d688c92832a8e48563270f7794960fba.setContent(html_d4f6a1c46ee4ab8ab3f6f1af2f9bdb82);
#
#
#
#         marker_60a1943d760f9599d7fa4404b732177f.bindPopup(popup_d688c92832a8e48563270f7794960fba)
#         ;
#
#
#
#
#             var marker_93b7bd8dba1424e19aea765aa34af2b6 = L.marker(
#                 [-33.94728

# %%
map_osm, map_dark = map_initialization()

# %%
for point in range(0, suburbs_location_list_size):
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='plus', angle=0, prefix='fa')).add_to(map_osm)   
    folium.Marker(suburbs_location_list[point], popup=df_suburbs['Suburb'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='plus', angle=0, prefix='fa')).add_to(map_dark)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b74b5e9726667704bc29733f4000d135 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b74b5e9726667704bc29733f4000d135&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b74b5e9726667704bc29733f4000d135 = L.map(
#                 &quot;map_b74b5e9726667704bc29733f4000d135&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_647c6b821ec08d46c0ea7f3f6bd39e58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_647c6b821ec08d46c0ea7f3f6bd39e58.addTo(map_b74b5e9726667704bc29733f4000d135);
#
#
#             var marker_d497d0d28b517cfdd3d7fcb2bd6d1066 = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_b74b5e9726667704bc29733f4000d135);
#
#
#             var icon_070423502861b7d0b9546f44fae1f2da = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d497d0d28b517cfdd3d7fcb2bd6d1066.setIcon(icon_070423502861b7d0b9546f44fae1f2da);
#
#
#         var popup_9752c317ec6109c4c85ab23bd7d0b080 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95835ab3f8f9bf8c5ac87754347b08cb = $(`&lt;div id=&quot;html_95835ab3f8f9bf8c5ac87754347b08cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_9752c317ec6109c4c85ab23bd7d0b080.setContent(html_95835ab3f8f9bf8c5ac87754347b08cb);
#
#
#
#         marker_d497d0d28b517cfdd3d7fcb2bd6d1066.bindPopup(popup_9752c317ec6109c4c85ab23bd7d0b080)
#         ;
#
#
#
#
#             var marker_d4765ab7700ab0f263ae887bd622785c = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_b74b5e9726667704bc29733f4000d135);
#
#
#             var icon_8602c49a5a094d128a8b6e722048bcab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d4765ab7700ab0f263ae887bd622785c.setIcon(icon_8602c49a5a094d128a8b6e722048bcab);
#
#
#         var popup_0a3ab5c46698689eab4772e48a16abb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_294b219e803eb44a2156238d586108c2 = $(`&lt;div id=&quot;html_294b219e803eb44a2156238d586108c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_0a3ab5c46698689eab4772e48a16abb9.setContent(html_294b219e803eb44a2156238d586108c2);
#
#
#
#         marker_d4765ab7700ab0f263ae887bd622785c.bindPopup(popup_0a3ab5c46698689eab4772e48a16abb9)
#         ;
#
#
#
#
#             var marker_c6b14486018482d0615dc34a599bbf5d = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_b74b5e9726667704bc29733f4000d135);
#
#
#             var icon_10b62a2241460872c4dcccbcead6c651 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c6b14486018482d0615dc34a599bbf5d.setIcon(icon_10b62a2241460872c4dcccbcead6c651);
#
#
#         var popup_42b42042e9cf395ead563964414656a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26793ec18d1949b8e3d047698ded283e = $(`&lt;div id=&quot;html_26793ec18d1949b8e3d047698ded283e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_42b42042e9cf395ead563964414656a1.setContent(html_26793ec18d1949b8e3d047698ded283e);
#
#
#
#         marker_c6b14486018482d0615dc34a599bbf5d.bindPopup(popup_42b42042e9cf395ead563964414656a1)
#         ;
#
#
#
#
#             var marker_5effdf820c0dd596681a232265b2b1e6 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_b74b5e9726667704bc29733f4000d135);
#
#
#             var icon_076a0813aff6aa64bc4e92c9345fa68b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c811294bdda917ab7dbee73cf322b05d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c811294bdda917ab7dbee73cf322b05d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c811294bdda917ab7dbee73cf322b05d = L.map(
#                 &quot;map_c811294bdda917ab7dbee73cf322b05d&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7812570f38b936a49689b060766d485 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b7812570f38b936a49689b060766d485.addTo(map_c811294bdda917ab7dbee73cf322b05d);
#
#
#             var marker_c7814b36880ea23b5cfd4d86af65a4db = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_c811294bdda917ab7dbee73cf322b05d);
#
#
#             var icon_c87931aad4ae7247856e835bc8b62e39 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c7814b36880ea23b5cfd4d86af65a4db.setIcon(icon_c87931aad4ae7247856e835bc8b62e39);
#
#
#         var popup_fc46cbed13b64c461374df3c942fcaad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73afaddc235d6a86ea4426875af73274 = $(`&lt;div id=&quot;html_73afaddc235d6a86ea4426875af73274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_fc46cbed13b64c461374df3c942fcaad.setContent(html_73afaddc235d6a86ea4426875af73274);
#
#
#
#         marker_c7814b36880ea23b5cfd4d86af65a4db.bindPopup(popup_fc46cbed13b64c461374df3c942fcaad)
#         ;
#
#
#
#
#             var marker_012dcee56947ee73e441f7fef92639c8 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_c811294bdda917ab7dbee73cf322b05d);
#
#
#             var icon_5e03e91df9ed972bbfe587c9333e4b8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_012dcee56947ee73e441f7fef92639c8.setIcon(icon_5e03e91df9ed972bbfe587c9333e4b8c);
#
#
#         var popup_167d7e95674d0298236432baadec0568 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30096b3e78ec045210875e387b0ee297 = $(`&lt;div id=&quot;html_30096b3e78ec045210875e387b0ee297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_167d7e95674d0298236432baadec0568.setContent(html_30096b3e78ec045210875e387b0ee297);
#
#
#
#         marker_012dcee56947ee73e441f7fef92639c8.bindPopup(popup_167d7e95674d0298236432baadec0568)
#         ;
#
#
#
#
#             var marker_809eba8b845dba89391c79c813bb1ede = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_c811294bdda917ab7dbee73cf322b05d);
#
#
#             var icon_40311114e191dada55e31e3498ebbdfb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_809eba8b845dba89391c79c813bb1ede.setIcon(icon_40311114e191dada55e31e3498ebbdfb);
#
#
#         var popup_0b93c6bd948c2f1a0a4e1fc2994e0d51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77a0adbf0981e4d8a1fac3b45f42a7d8 = $(`&lt;div id=&quot;html_77a0adbf0981e4d8a1fac3b45f42a7d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_0b93c6bd948c2f1a0a4e1fc2994e0d51.setContent(html_77a0adbf0981e4d8a1fac3b45f42a7d8);
#
#
#
#         marker_809eba8b845dba89391c79c813bb1ede.bindPopup(popup_0b93c6bd948c2f1a0a4e1fc2994e0d51)
#         ;
#
#
#
#
#             var marker_5798a9cf2964901cbac0e1db0fbb5628 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_c811294bdda917ab7dbee73cf322b05d);
#
#
#             var icon_2639a01fa0668df7ad2de0224afe5233 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &

# %%
# Classification
map_osm, map_dark = map_initialization()
for point in range(0, suburbs_location_list_size):
    if df_suburbs['Oct 2017\nkl/month'][point] <= 5:
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='green', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_dark)

    elif df_suburbs['Oct 2017\nkl/month'][point] > 5 and df_suburbs['Oct 2017\nkl/month'][point] <= 8:
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='blue', icon_color='white', icon='thumbs-up', angle=0, prefix='fa')).add_to(map_dark)
    
    else:
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_osm)
        folium.Marker(suburbs_location_list[point],
                      popup=df_suburbs['Suburb'][point],
                      icon=folium.Icon(color='red', icon_color='white', icon='thumbs-down', angle=0, prefix='fa')).add_to(map_dark)
        

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a82307414372a12e8ee131e1661cd2c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a82307414372a12e8ee131e1661cd2c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a82307414372a12e8ee131e1661cd2c3 = L.map(
#                 &quot;map_a82307414372a12e8ee131e1661cd2c3&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9735716909de2c28ed8c588cc8fc3adf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9735716909de2c28ed8c588cc8fc3adf.addTo(map_a82307414372a12e8ee131e1661cd2c3);
#
#
#             var marker_2dd1a596c379979c47a2751ad2e2370d = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_a82307414372a12e8ee131e1661cd2c3);
#
#
#             var icon_0c1c692a3f6f95dcdb82407395303a2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2dd1a596c379979c47a2751ad2e2370d.setIcon(icon_0c1c692a3f6f95dcdb82407395303a2c);
#
#
#         var popup_9a11b4ae4da928baf497c81a74cdb782 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10205d15f6ed099b2108f826435f7372 = $(`&lt;div id=&quot;html_10205d15f6ed099b2108f826435f7372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_9a11b4ae4da928baf497c81a74cdb782.setContent(html_10205d15f6ed099b2108f826435f7372);
#
#
#
#         marker_2dd1a596c379979c47a2751ad2e2370d.bindPopup(popup_9a11b4ae4da928baf497c81a74cdb782)
#         ;
#
#
#
#
#             var marker_921f0c9ba3d32325ddc2c91b32c72179 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_a82307414372a12e8ee131e1661cd2c3);
#
#
#             var icon_361256789725a7438892461623f0e0b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_921f0c9ba3d32325ddc2c91b32c72179.setIcon(icon_361256789725a7438892461623f0e0b0);
#
#
#         var popup_9d25fc1396ab428d04e9a209d54d6d35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adef0685ca53b7fce731d62a5e9649c8 = $(`&lt;div id=&quot;html_adef0685ca53b7fce731d62a5e9649c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_9d25fc1396ab428d04e9a209d54d6d35.setContent(html_adef0685ca53b7fce731d62a5e9649c8);
#
#
#
#         marker_921f0c9ba3d32325ddc2c91b32c72179.bindPopup(popup_9d25fc1396ab428d04e9a209d54d6d35)
#         ;
#
#
#
#
#             var marker_a35fb450b7aceb7870c791e2ed59208b = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_a82307414372a12e8ee131e1661cd2c3);
#
#
#             var icon_1db6bd68d3914a57e77b02a90e2a606c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a35fb450b7aceb7870c791e2ed59208b.setIcon(icon_1db6bd68d3914a57e77b02a90e2a606c);
#
#
#         var popup_5f9930d74543e47bbab488be11daadce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_543339e70c0912e5b1850b0fb48c0aa1 = $(`&lt;div id=&quot;html_543339e70c0912e5b1850b0fb48c0aa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_5f9930d74543e47bbab488be11daadce.setContent(html_543339e70c0912e5b1850b0fb48c0aa1);
#
#
#
#         marker_a35fb450b7aceb7870c791e2ed59208b.bindPopup(popup_5f9930d74543e47bbab488be11daadce)
#         ;
#
#
#
#
#             var marker_e4c3da1f3f13717d886c0895138ffda6 = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_a82307414372a12e8ee131e1661cd2c3);
#
#
#             var icon_d332988d84b00548a6c94e479bc3340a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot

# %%
map_dark
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_275ff06dad1f6c5767b3f0fdee01e69f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_275ff06dad1f6c5767b3f0fdee01e69f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_275ff06dad1f6c5767b3f0fdee01e69f = L.map(
#                 &quot;map_275ff06dad1f6c5767b3f0fdee01e69f&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56f4657a64f78ebe2b53cff596db4711 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_56f4657a64f78ebe2b53cff596db4711.addTo(map_275ff06dad1f6c5767b3f0fdee01e69f);
#
#
#             var marker_2bc6b84bedce5bbe55128d5be240feae = L.marker(
#                 [-33.96722, 18.50214],
#                 {}
#             ).addTo(map_275ff06dad1f6c5767b3f0fdee01e69f);
#
#
#             var icon_23ac41d1204581317b5533c4d4758e02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2bc6b84bedce5bbe55128d5be240feae.setIcon(icon_23ac41d1204581317b5533c4d4758e02);
#
#
#         var popup_8980f3e5e6035acb39a6a19659158b40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_feb4343c98097d41d14f7899952402c3 = $(`&lt;div id=&quot;html_feb4343c98097d41d14f7899952402c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE&lt;/div&gt;`)[0];
#                 popup_8980f3e5e6035acb39a6a19659158b40.setContent(html_feb4343c98097d41d14f7899952402c3);
#
#
#
#         marker_2bc6b84bedce5bbe55128d5be240feae.bindPopup(popup_8980f3e5e6035acb39a6a19659158b40)
#         ;
#
#
#
#
#             var marker_bfb397be7b0b85aea4abd8e6508391b1 = L.marker(
#                 [-32.705958, 18.485135],
#                 {}
#             ).addTo(map_275ff06dad1f6c5767b3f0fdee01e69f);
#
#
#             var icon_a51000808012b66f1dc973871e51da93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bfb397be7b0b85aea4abd8e6508391b1.setIcon(icon_a51000808012b66f1dc973871e51da93);
#
#
#         var popup_2bb6026ee6bdafbf47fee814be4d96cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a103b9b707f16a4fb3aa1cda9861f7d = $(`&lt;div id=&quot;html_7a103b9b707f16a4fb3aa1cda9861f7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA&lt;/div&gt;`)[0];
#                 popup_2bb6026ee6bdafbf47fee814be4d96cf.setContent(html_7a103b9b707f16a4fb3aa1cda9861f7d);
#
#
#
#         marker_bfb397be7b0b85aea4abd8e6508391b1.bindPopup(popup_2bb6026ee6bdafbf47fee814be4d96cf)
#         ;
#
#
#
#
#             var marker_f5db29537f0ce308059e2e8ae989b265 = L.marker(
#                 [-33.927953, 18.382592],
#                 {}
#             ).addTo(map_275ff06dad1f6c5767b3f0fdee01e69f);
#
#
#             var icon_557ac5de5a8864f49c1e47e5d1b29b41 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f5db29537f0ce308059e2e8ae989b265.setIcon(icon_557ac5de5a8864f49c1e47e5d1b29b41);
#
#
#         var popup_ffbd36745ac13a8ca8ab732464e5d9c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4694ac7944171a086b0aa4bcdb78ca3 = $(`&lt;div id=&quot;html_e4694ac7944171a086b0aa4bcdb78ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY&lt;/div&gt;`)[0];
#                 popup_ffbd36745ac13a8ca8ab732464e5d9c4.setContent(html_e4694ac7944171a086b0aa4bcdb78ca3);
#
#
#
#         marker_f5db29537f0ce308059e2e8ae989b265.bindPopup(popup_ffbd36745ac13a8ca8ab732464e5d9c4)
#         ;
#
#
#
#
#             var marker_c6bae6684b278885575758f042340fdf = L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_275ff06dad1f6c5767b3f0fdee01e69f);
#
#
#             var icon_cf33d72b88948ea228c9e4d2c0cbcf04 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %%
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + 'kl',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)

map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a25ac77ad03e163e61d76c4074e4a38b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a25ac77ad03e163e61d76c4074e4a38b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a25ac77ad03e163e61d76c4074e4a38b = L.map(
#                 &quot;map_a25ac77ad03e163e61d76c4074e4a38b&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eae1ca69172629abb3ef78c747a5f9d1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eae1ca69172629abb3ef78c747a5f9d1.addTo(map_a25ac77ad03e163e61d76c4074e4a38b);
#
#
#             var circle_2662481362d939c54470e24baa0ce8a9 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_a25ac77ad03e163e61d76c4074e4a38b);
#
#
#         var popup_2a8114fe8f80084d764efc0da25f3198 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3c497d62731bef8e7989d2812ef817e = $(`&lt;div id=&quot;html_f3c497d62731bef8e7989d2812ef817e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11kl&lt;/div&gt;`)[0];
#                 popup_2a8114fe8f80084d764efc0da25f3198.setContent(html_f3c497d62731bef8e7989d2812ef817e);
#
#
#
#         circle_2662481362d939c54470e24baa0ce8a9.bindPopup(popup_2a8114fe8f80084d764efc0da25f3198)
#         ;
#
#
#
#
#             var circle_e782157e0db36019a1cb7d9d3d89fe44 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_a25ac77ad03e163e61d76c4074e4a38b);
#
#
#         var popup_2b21f1c47342d876fefb766e9c32c513 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1640b92512f4453cc5af6cf29f7730d = $(`&lt;div id=&quot;html_f1640b92512f4453cc5af6cf29f7730d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10kl&lt;/div&gt;`)[0];
#                 popup_2b21f1c47342d876fefb766e9c32c513.setContent(html_f1640b92512f4453cc5af6cf29f7730d);
#
#
#
#         circle_e782157e0db36019a1cb7d9d3d89fe44.bindPopup(popup_2b21f1c47342d876fefb766e9c32c513)
#         ;
#
#
#
#
#             var circle_29c3ce014b354b188edd7c2b9d385bc9 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_a25ac77ad03e163e61d76c4074e4a38b);
#
#
#         var popup_dac8702b1d473a3c4cf69a81888a263e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eecfb0247846bdea6d3389f1d98e0f85 = $(`&lt;div id=&quot;html_eecfb0247846bdea6d3389f1d98e0f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13kl&lt;/div&gt;`)[0];
#                 popup_dac8702b1d473a3c4cf69a81888a263e.setContent(html_eecfb0247846bdea6d3389f1d98e0f85);
#
#
#
#         circle_29c3ce014b354b188edd7c2b9d385bc9.bindPopup(popup_dac8702b1d473a3c4cf69a81888a263e)
#         ;
#
#
#
#
#             var circle_136a53ae2420c84996effd01cfec5a1b = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;d

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'

    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + 'kl',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)

map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8de5e6c1a06c79f1db981ca08c1aeae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8de5e6c1a06c79f1db981ca08c1aeae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8de5e6c1a06c79f1db981ca08c1aeae = L.map(
#                 &quot;map_d8de5e6c1a06c79f1db981ca08c1aeae&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3e55c5ab20d34b21241e0c5acf8e894 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e3e55c5ab20d34b21241e0c5acf8e894.addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#             var circle_c3b9faeab690ca67b31625ffe2bef144 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_3d0bfb8397df28943b68c21263d1de92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39439c2cbcedb058ad6b2a703525a668 = $(`&lt;div id=&quot;html_39439c2cbcedb058ad6b2a703525a668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11kl&lt;/div&gt;`)[0];
#                 popup_3d0bfb8397df28943b68c21263d1de92.setContent(html_39439c2cbcedb058ad6b2a703525a668);
#
#
#
#         circle_c3b9faeab690ca67b31625ffe2bef144.bindPopup(popup_3d0bfb8397df28943b68c21263d1de92)
#         ;
#
#
#
#
#             var circle_7010e598f42242687289946622f9321e = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_43769d8c4dad777658a11370c3f3a272 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da94186d1a83966251ffb64a881ac08d = $(`&lt;div id=&quot;html_da94186d1a83966251ffb64a881ac08d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10kl&lt;/div&gt;`)[0];
#                 popup_43769d8c4dad777658a11370c3f3a272.setContent(html_da94186d1a83966251ffb64a881ac08d);
#
#
#
#         circle_7010e598f42242687289946622f9321e.bindPopup(popup_43769d8c4dad777658a11370c3f3a272)
#         ;
#
#
#
#
#             var circle_f88bde0a36450a46e7123b28cd6a0fa8 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_9622bed5af8c49691db1fd0950ad09c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2c8ac9e362f88fe396b03e7b759a2b2 = $(`&lt;div id=&quot;html_d2c8ac9e362f88fe396b03e7b759a2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13kl&lt;/div&gt;`)[0];
#                 popup_9622bed5af8c49691db1fd0950ad09c2.setContent(html_d2c8ac9e362f88fe396b03e7b759a2b2);
#
#
#
#         circle_f88bde0a36450a46e7123b28cd6a0fa8.bindPopup(popup_9622bed5af8c49691db1fd0950ad09c2)
#         ;
#
#
#
#
#             var circle_8fb86794d2846811a35523a804e5ef66 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %%
# Building choropleth map dataset

df_world_countries = pd.read_json(r'C:\Users\ebisys\Documents\world-countries.json')
df_unemployment = pd.read_csv(r'C:\Users\ebisys\Documents\unemployment.csv', skiprows=4, delimiter=',')

df_unemployment.head(10)
# Out:
#            Country Name Country Code  \
# 0                 Aruba          ABW
# 1           Afghanistan          AFG
# 2                Angola          AGO
# 3               Albania          ALB
# 4               Andorra          AND
# 5            Arab World          ARB
# 6  United Arab Emirates          ARE
# 7             Argentina          ARG
# 8               Armenia          ARM
# 9        American Samoa          ASM
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 5  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 6  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 7  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 8  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 9  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2010       2011       2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   7.821000   8.230000   7.936000
# 2   NaN   NaN   NaN   NaN   NaN  ...   9.863000   7.360000   7.347000
# 3   NaN   NaN   NaN   NaN   NaN  ...  14.200000  13.980000  13.440000
# 4   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 5   NaN   NaN   NaN   NaN   NaN  ...   9.959137  10.294118  10.431499
# 6   NaN   NaN   NaN   NaN   NaN  ...   3.695000   3.305000   2.971000
# 7   NaN   NaN   NaN   NaN   NaN  ...   7.710000   7.180000   7.220000
# 8   NaN   NaN   NaN   NaN   NaN  ...  19.010000  18.440001  17.309999
# 9   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
#
#         2013       2014       2015       2016       2017       2018  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   8.452000   8.706000   8.864000   8.841000   8.837000   8.808000
# 2   7.331000   7.306000   7.281000   7.724000   8.167000   8.543000
# 3  15.640000  17.490000  17.080000  15.220000  13.867000  15.132000
# 4        NaN        NaN        NaN        NaN        NaN        NaN
# 5  10.293865  10.289091  10.266855  10.019851   9.930642   9.808109
# 6   2.618000   2.282000   1.933000   1.636000   1.672000   1.710000
# 7   7.100000   7.270000   7.151000   8.696000   8.518000   8.162000
# 8  16.180000  17.500000  18.260000  18.040001  18.233999  18.275999
# 9        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 63
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
#
# [10 rows x 64 columns]

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)
# Out:
#            Country Name Country Code       2018
# 0                 Aruba          ABW        NaN
# 1           Afghanistan          AFG   8.808000
# 2                Angola          AGO   8.543000
# 3               Albania          ALB  15.132000
# 4               Andorra          AND        NaN
# 5            Arab World          ARB   9.808109
# 6  United Arab Emirates          ARE   1.710000
# 7             Argentina          ARG   8.162000
# 8               Armenia          ARM  18.275999
# 9        American Samoa          ASM        NaN

# %%
# Remove nulls
df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)
# Out:
#             Country Name Country Code       2018
# 1            Afghanistan          AFG   8.808000
# 2                 Angola          AGO   8.543000
# 3                Albania          ALB  15.132000
# 5             Arab World          ARB   9.808109
# 6   United Arab Emirates          ARE   1.710000
# 7              Argentina          ARG   8.162000
# 8                Armenia          ARM  18.275999
# 11             Australia          AUS   5.474000
# 12               Austria          AUT   5.387000
# 13            Azerbaijan          AZE   5.037000

# %%
df_unemployment_2018_clean.shape
# Out:
# (233, 3)

# %%
# Prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()
# Out:
#   Country Code       2018
# 1          AFG   8.808000
# 2          AGO   8.543000
# 3          ALB  15.132000
# 5          ARB   9.808109
# 6          ARE   1.710000

# %%
# Create the map
map_unemployment = folium.Map(location=[8.7832, 34.5058], zoom_start=3)

folium.Choropleth(geo_data=r'C:\Users\ebisys\Documents\world-countries.json',
                  data=data_unemployment,
                  columns=['Country Code', '2018'],
                  key_on='feature.id',
                  fill_color='YlOrRd',
                  fill_opacity=0.7,
                  line_opacity=0.2,
                  legend_name=legendTitle
                 ).add_to(map_unemployment)

map_unemployment
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_753e6e6dcba1a453c8dc2be54d252ef8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_753e6e6dcba1a453c8dc2be54d252ef8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_753e6e6dcba1a453c8dc2be54d252ef8 = L.map(
#                 &quot;map_753e6e6dcba1a453c8dc2be54d252ef8&quot;,
#                 {
#                     center: [8.7832, 34.5058],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34aaf7ee824e09af8f795bf1be1d6f8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_34aaf7ee824e09af8f795bf1be1d6f8d.addTo(map_753e6e6dcba1a453c8dc2be54d252ef8);
#
#
#             var choropleth_0b9259c62017118d42eecfc948d32c39 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_b0650726521de831855204036d63ae1f_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Angola&quot;: case &quot;Argentina&quot;: case &quot;Australia&quot;: case &quot;Austria&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Burkina Faso&quot;: case &quot;Bulgaria&quot;: case &quot;Belize&quot;: case &quot;Brunei&quot;: case &quot;Central African Republic&quot;: case &quot;Canada&quot;: case &quot;Chile&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Djibouti&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Eritrea&quot;: case &quot;Estonia&quot;: case &quot;Ethiopia&quot;: case &quot;Finland&quot;: case &quot;Fiji&quot;: case &quot;France&quot;: case &quot;Gambia&quot;: case &quot;Guinea Bissau&quot;: case &quot;Equatorial Guinea&quot;: case &quot;Croatia&quot;: case &quot;Ireland&quot;: case &quot;Iraq&quot;: case &quot;Kazakhstan&quot;: case &quot;Kyrgyzstan&quot;: case &quot;Lebanon&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mali&quot;: case &quot;Mongolia&quot;: case &quot;Malawi&quot;: case &quot;Nigeria&quot;: case &quot;New Zealand&quot;: case &quot;Portugal&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;Somalia&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Chad&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Ukraine&quot;: case &quot;Uruguay&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Botswana&quot;: case &quot;Spain&quot;: case &quot;Jordan&quot;: case &quot;Libya&quot;: case &quot;Montenegro&quot;: case &quot;New Caledonia&quot;: case &quot;Syria&quot;: case &quot;Tunisia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;Northern Cyprus&quot;: case &quot;Falkland Islands&quot;: case &quot;Greenland&quot;: case &quot;Kosovo&quot;: case &quot;Western Sahara&quot;: case &quot;South Sudan&quot;: case &quot;Somaliland&quot;: case &quot;Taiwan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;The Bahamas&quot;: case &quot;Brazil&quot;: case &quot;Republic of the Congo&quot;: case &quot;Cyprus&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Georgia&quot;: case &quot;Guyana&quot;: case &quot;Haiti&quot;: case &quot;Iran&quot;: case &quot;Italy&quot;: case &quot;Jamaica&quot;: case &quot;Kenya&quot;: case &quot;Mauritania&quot;: case &quot;Puerto Rico&quot;: case &quot;Sudan&quot;: case &quot;Republic of Serbia&quot;: case &quot;Tajikistan&quot;: case &quot;Turkey&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bosnia and Herzegovina&quot;: case &quot;Lesotho&quot;: case &quot;Mozambique&quot;: case &quot;Swaziland&quot;: case &quot;West Bank&quot;: case &quot;South Africa&quot;:

# %%
# Measuring Boundaries

df_damLevels = pd.read_csv(r'https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/refs/heads/master/DamLevels.txt', delimiter=',')
df_damLevels.head(10)
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras-Lower Dam        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras-Upper Dam        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
# 5      Wemmershoek Dam          Wemmers River  Photo  Indicators   58.8
#
#    ThisWeek  LastWeek  LastYear
# 0      73.7      75.2      49.9
# 1      50.2      51.7      35.6
# 2      70.0      69.8      92.4
# 3      40.9      41.9      10.6
# 4      65.6      67.5      15.5
# 5      61.8      63.5      44.9

# %%
df_location = pd.read_csv(r'https://raw.githubusercontent.com/EBISYS/Mapping-Dam-Levels/refs/heads/master/damLocations.txt', delimiter=',')
df_location.head()
# Out:
#                    Dam   Latitude  Longitude
# 0       Berg River Dam -33.925000  19.060833
# 1  Steenbras-Upper Dam -34.166300  18.910000
# 2  Steenbras-Lower Dam -34.179722  18.876389
# 3  Theewaterskloof Dam -34.078100  19.289200
# 4         Voelvlei Dam -33.337500  19.033600

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')
df_damData.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras-Lower Dam        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras-Upper Dam        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear   Latitude  Longitude
# 0      73.7      75.2      49.9 -33.925000  19.060833
# 1      50.2      51.7      35.6 -34.179722  18.876389
# 2      70.0      69.8      92.4 -34.166300  18.910000
# 3      40.9      41.9      10.6 -34.078100  19.289200
# 4      65.6      67.5      15.5 -33.337500  19.033600

# %%
# Prepare data to plot
df_dam_locations = df_damData[['Latitude', 'Longitude']]
dam_location_list = df_dam_locations.values.tolist()
dam_location_list_size = len(dam_location_list)
dam_location_list_size
# Out:
# 6

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dam_location_list_size):
    folium.Marker(dam_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)

map_dams
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8049b1482cd258cc2cb44a9a96cd5a62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8049b1482cd258cc2cb44a9a96cd5a62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8049b1482cd258cc2cb44a9a96cd5a62 = L.map(
#                 &quot;map_8049b1482cd258cc2cb44a9a96cd5a62&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2106a4c991568b84b5dc49282a50d4e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a2106a4c991568b84b5dc49282a50d4e.addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#             var marker_6a075b9dbfe29ce7cf556b7b6d3c7e33 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#         var popup_f1392f5039550bc2add536fc33010de0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0db628b599556095d92fadac344f0f77 = $(`&lt;div id=&quot;html_0db628b599556095d92fadac344f0f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_f1392f5039550bc2add536fc33010de0.setContent(html_0db628b599556095d92fadac344f0f77);
#
#
#
#         marker_6a075b9dbfe29ce7cf556b7b6d3c7e33.bindPopup(popup_f1392f5039550bc2add536fc33010de0)
#         ;
#
#
#
#
#             var marker_98a47dc431e4630780c090690c0a9052 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#         var popup_c5f61a167b7b4105e6a5568c3806a20e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_76ffac0e0c549e7037c520c7a73c305e = $(`&lt;div id=&quot;html_76ffac0e0c549e7037c520c7a73c305e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Lower Dam&lt;/div&gt;`)[0];
#                 popup_c5f61a167b7b4105e6a5568c3806a20e.setContent(html_76ffac0e0c549e7037c520c7a73c305e);
#
#
#
#         marker_98a47dc431e4630780c090690c0a9052.bindPopup(popup_c5f61a167b7b4105e6a5568c3806a20e)
#         ;
#
#
#
#
#             var marker_396f990b30af9cadea6e2a578205fab3 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#         var popup_279e59230978654934280b20f2b7f4d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be3e3ca11bbb44a4999ce807845b6ed6 = $(`&lt;div id=&quot;html_be3e3ca11bbb44a4999ce807845b6ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Upper Dam&lt;/div&gt;`)[0];
#                 popup_279e59230978654934280b20f2b7f4d3.setContent(html_be3e3ca11bbb44a4999ce807845b6ed6);
#
#
#
#         marker_396f990b30af9cadea6e2a578205fab3.bindPopup(popup_279e59230978654934280b20f2b7f4d3)
#         ;
#
#
#
#
#             var marker_63eb7544509605a1ef010c13978f818d = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#         var popup_edcc31b4fd36167db324e1badefb6931 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b3ad896047efc28407018dc092d942c = $(`&lt;div id=&quot;html_2b3ad896047efc28407018dc092d942c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_edcc31b4fd36167db324e1badefb6931.setContent(html_2b3ad896047efc28407018dc092d942c);
#
#
#
#         marker_63eb7544509605a1ef010c13978f818d.bindPopup(popup_edcc31b4fd36167db324e1badefb6931)
#         ;
#
#
#
#
#             var marker_34d6e90eea748b68a4a3d40c10732b97 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);
#
#
#         var popup_5ff3c73cefee8bb29d819c11fa5a72d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54312bd49cf49b5a253419e7248a7c41 = $(`&lt;div id=&quot;html_54312bd49cf49b5a253419e7248a7c41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_5ff3c73cefee8bb29d819c11fa5a72d5.setContent(html_54312bd49cf49b5a253419e7248a7c41);
#
#
#
#         marker_34d6e90eea748b68a4a3d40c10732b97.bindPopup(popup_5ff3c73cefee8bb29d819c11fa5a72d5)
#         ;
#
#
#
#
#             var marker_2378b96bff61f7955ae89291253385c3 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_8049b1482cd258cc2cb44a9a96cd5a62);

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                     tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                     zoom_start=12,
                     attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dam_location_list_size):
    folium.Marker(dam_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28e84b0e769120b966270aa14d51c598 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28e84b0e769120b966270aa14d51c598&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28e84b0e769120b966270aa14d51c598 = L.map(
#                 &quot;map_28e84b0e769120b966270aa14d51c598&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f22b90ee2f14ada06237013cde8f63b = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f22b90ee2f14ada06237013cde8f63b.addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#             var marker_452202738bff276ad571811fa4b1abfa = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_8ad5ca9fa76a34eb172de416f5243329 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d35a532822d91eabfc4f132cb0f1519 = $(`&lt;div id=&quot;html_2d35a532822d91eabfc4f132cb0f1519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_8ad5ca9fa76a34eb172de416f5243329.setContent(html_2d35a532822d91eabfc4f132cb0f1519);
#
#
#
#         marker_452202738bff276ad571811fa4b1abfa.bindPopup(popup_8ad5ca9fa76a34eb172de416f5243329)
#         ;
#
#
#
#
#             var marker_48aa6ed3c0b78475c88d4abad715b863 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_3fff09bbea634f7c782bbb6458f555fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d1340bd0c92ee82a345f95b9a3cda9d = $(`&lt;div id=&quot;html_7d1340bd0c92ee82a345f95b9a3cda9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Lower Dam&lt;/div&gt;`)[0];
#                 popup_3fff09bbea634f7c782bbb6458f555fb.setContent(html_7d1340bd0c92ee82a345f95b9a3cda9d);
#
#
#
#         marker_48aa6ed3c0b78475c88d4abad715b863.bindPopup(popup_3fff09bbea634f7c782bbb6458f555fb)
#         ;
#
#
#
#
#             var marker_7f15eab7213aa64a95ac74bfee2b63f4 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_dd69d775d0b8c2711a58d46fae43856f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5286a0527737068742ca886f6cfba8ff = $(`&lt;div id=&quot;html_5286a0527737068742ca886f6cfba8ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Upper Dam&lt;/div&gt;`)[0];
#                 popup_dd69d775d0b8c2711a58d46fae43856f.setContent(html_5286a0527737068742ca886f6cfba8ff);
#
#
#
#         marker_7f15eab7213aa64a95ac74bfee2b63f4.bindPopup(popup_dd69d775d0b8c2711a58d46fae43856f)
#         ;
#
#
#
#
#             var marker_2b17da7ae5e877fb081238c28f5c7ec2 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_bd545c1312b401c00e9b52a62d18f7d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90d4fe03dbcb1988810f865f8561a400 = $(`&lt;div id=&quot;html_90d4fe03dbcb1988810f865f8561a400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_bd545c1312b401c00e9b52a62d18f7d6.setContent(html_90d4fe03dbcb1988810f865f8561a400);
#
#
#
#         marker_2b17da7ae5e877fb081238c28f5c7ec2.bindPopup(popup_bd545c1312b401c00e9b52a62d18f7d6)
#         ;
#
#
#
#
#             var marker_c6f52c1111febba5e903799f56cdf27b = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_d282e58779d6aea5eb7b437619d09893 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e38c0298126cfd9ad7b2231c85e681d9 = $(`&lt;div id=&quot;html_e38c0298126cfd9ad7b2231c85e681d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_d282e58779d6aea5eb7b437619d09893.setContent(html_e38c0298126cfd9ad7b2231c85e681d9);
#
#
#
#         marker_c6f52c1111febba5e903799f56cdf27b.bindPopup(popup_d282e58779d6aea5eb7b437619d09893)
#         ;
#
#
#
#
#             var marker_390db497efd87d0148ffe69542de29b3 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28e84b0e769120b966270aa14d51c598 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28e84b0e769120b966270aa14d51c598&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28e84b0e769120b966270aa14d51c598 = L.map(
#                 &quot;map_28e84b0e769120b966270aa14d51c598&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f22b90ee2f14ada06237013cde8f63b = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f22b90ee2f14ada06237013cde8f63b.addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#             var marker_452202738bff276ad571811fa4b1abfa = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_8ad5ca9fa76a34eb172de416f5243329 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d35a532822d91eabfc4f132cb0f1519 = $(`&lt;div id=&quot;html_2d35a532822d91eabfc4f132cb0f1519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_8ad5ca9fa76a34eb172de416f5243329.setContent(html_2d35a532822d91eabfc4f132cb0f1519);
#
#
#
#         marker_452202738bff276ad571811fa4b1abfa.bindPopup(popup_8ad5ca9fa76a34eb172de416f5243329)
#         ;
#
#
#
#
#             var marker_48aa6ed3c0b78475c88d4abad715b863 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_3fff09bbea634f7c782bbb6458f555fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d1340bd0c92ee82a345f95b9a3cda9d = $(`&lt;div id=&quot;html_7d1340bd0c92ee82a345f95b9a3cda9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Lower Dam&lt;/div&gt;`)[0];
#                 popup_3fff09bbea634f7c782bbb6458f555fb.setContent(html_7d1340bd0c92ee82a345f95b9a3cda9d);
#
#
#
#         marker_48aa6ed3c0b78475c88d4abad715b863.bindPopup(popup_3fff09bbea634f7c782bbb6458f555fb)
#         ;
#
#
#
#
#             var marker_7f15eab7213aa64a95ac74bfee2b63f4 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_dd69d775d0b8c2711a58d46fae43856f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5286a0527737068742ca886f6cfba8ff = $(`&lt;div id=&quot;html_5286a0527737068742ca886f6cfba8ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras-Upper Dam&lt;/div&gt;`)[0];
#                 popup_dd69d775d0b8c2711a58d46fae43856f.setContent(html_5286a0527737068742ca886f6cfba8ff);
#
#
#
#         marker_7f15eab7213aa64a95ac74bfee2b63f4.bindPopup(popup_dd69d775d0b8c2711a58d46fae43856f)
#         ;
#
#
#
#
#             var marker_2b17da7ae5e877fb081238c28f5c7ec2 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_bd545c1312b401c00e9b52a62d18f7d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90d4fe03dbcb1988810f865f8561a400 = $(`&lt;div id=&quot;html_90d4fe03dbcb1988810f865f8561a400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_bd545c1312b401c00e9b52a62d18f7d6.setContent(html_90d4fe03dbcb1988810f865f8561a400);
#
#
#
#         marker_2b17da7ae5e877fb081238c28f5c7ec2.bindPopup(popup_bd545c1312b401c00e9b52a62d18f7d6)
#         ;
#
#
#
#
#             var marker_c6f52c1111febba5e903799f56cdf27b = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_28e84b0e769120b966270aa14d51c598);
#
#
#         var popup_d282e58779d6aea5eb7b437619d09893 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e38c0298126cfd9ad7b2231c85e681d9 = $(`&lt;div id=&quot;html_e38c0298126cfd9ad7b2231c85e681d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_d282e58779d6aea5eb7b437619d09893.setContent(html_e38c0298126cfd9ad7b2231c85e681d9);

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')

for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)

folium.LayerControl().add_to(map_layers)

map_layers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8de5e6c1a06c79f1db981ca08c1aeae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8de5e6c1a06c79f1db981ca08c1aeae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8de5e6c1a06c79f1db981ca08c1aeae = L.map(
#                 &quot;map_d8de5e6c1a06c79f1db981ca08c1aeae&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3e55c5ab20d34b21241e0c5acf8e894 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e3e55c5ab20d34b21241e0c5acf8e894.addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#             var circle_c3b9faeab690ca67b31625ffe2bef144 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_3d0bfb8397df28943b68c21263d1de92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39439c2cbcedb058ad6b2a703525a668 = $(`&lt;div id=&quot;html_39439c2cbcedb058ad6b2a703525a668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11kl&lt;/div&gt;`)[0];
#                 popup_3d0bfb8397df28943b68c21263d1de92.setContent(html_39439c2cbcedb058ad6b2a703525a668);
#
#
#
#         circle_c3b9faeab690ca67b31625ffe2bef144.bindPopup(popup_3d0bfb8397df28943b68c21263d1de92)
#         ;
#
#
#
#
#             var circle_7010e598f42242687289946622f9321e = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_43769d8c4dad777658a11370c3f3a272 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da94186d1a83966251ffb64a881ac08d = $(`&lt;div id=&quot;html_da94186d1a83966251ffb64a881ac08d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10kl&lt;/div&gt;`)[0];
#                 popup_43769d8c4dad777658a11370c3f3a272.setContent(html_da94186d1a83966251ffb64a881ac08d);
#
#
#
#         circle_7010e598f42242687289946622f9321e.bindPopup(popup_43769d8c4dad777658a11370c3f3a272)
#         ;
#
#
#
#
#             var circle_f88bde0a36450a46e7123b28cd6a0fa8 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_d8de5e6c1a06c79f1db981ca08c1aeae);
#
#
#         var popup_9622bed5af8c49691db1fd0950ad09c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2c8ac9e362f88fe396b03e7b759a2b2 = $(`&lt;div id=&quot;html_d2c8ac9e362f88fe396b03e7b759a2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13kl&lt;/div&gt;`)[0];
#                 popup_9622bed5af8c49691db1fd0950ad09c2.setContent(html_d2c8ac9e362f88fe396b03e7b759a2b2);
#
#
#
#         circle_f88bde0a36450a46e7123b28cd6a0fa8.bindPopup(popup_9622bed5af8c49691db1fd0950ad09c2)
#         ;
#
#
#
#
#             var circle_8fb86794d2846811a35523a804e5ef66 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %%
# Creating Heat Map
from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kl',
        radius=15,
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)

# Convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6515eb681b348a73266806ba07266ad7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6515eb681b348a73266806ba07266ad7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6515eb681b348a73266806ba07266ad7 = L.map(
#                 &quot;map_6515eb681b348a73266806ba07266ad7&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be0309e264cf7c26b97c74cb6d43ada7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be0309e264cf7c26b97c74cb6d43ada7.addTo(map_6515eb681b348a73266806ba07266ad7);
#
#
#             var circle_037c449e0ca9ccb56ff2583bc49a4a98 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_6515eb681b348a73266806ba07266ad7);
#
#
#         var popup_f095b5e1eb0f651141aa8ba7168836f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_259fbe42dfa7c49b33bf8c2924a69f1c = $(`&lt;div id=&quot;html_259fbe42dfa7c49b33bf8c2924a69f1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kl&lt;/div&gt;`)[0];
#                 popup_f095b5e1eb0f651141aa8ba7168836f9.setContent(html_259fbe42dfa7c49b33bf8c2924a69f1c);
#
#
#
#         circle_037c449e0ca9ccb56ff2583bc49a4a98.bindPopup(popup_f095b5e1eb0f651141aa8ba7168836f9)
#         ;
#
#
#
#
#             var circle_ceb9fbbc530b5792fb4928411e47f677 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_6515eb681b348a73266806ba07266ad7);
#
#
#         var popup_88005d532274aa9a7c095c0268999c59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7de2914eb07ab2d6ae0d43149eac172e = $(`&lt;div id=&quot;html_7de2914eb07ab2d6ae0d43149eac172e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kl&lt;/div&gt;`)[0];
#                 popup_88005d532274aa9a7c095c0268999c59.setContent(html_7de2914eb07ab2d6ae0d43149eac172e);
#
#
#
#         circle_ceb9fbbc530b5792fb4928411e47f677.bindPopup(popup_88005d532274aa9a7c095c0268999c59)
#         ;
#
#
#
#
#             var circle_fabd84f7d1c8429b6f39095ecfa366ba = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_6515eb681b348a73266806ba07266ad7);
#
#
#         var popup_17dbd4606d4ed446a7ca9a3187fa7e7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0401cb5a7cbedac1917b8c93a1c9783 = $(`&lt;div id=&quot;html_c0401cb5a7cbedac1917b8c93a1c9783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kl&lt;/div&gt;`)[0];
#                 popup_17dbd4606d4ed446a7ca9a3187fa7e7d.setContent(html_c0401cb5a7cbedac1917b8c93a1c9783);
#
#
#
#         circle_fabd84f7d1c8429b6f39095ecfa366ba.bindPopup(popup_17dbd4606d4ed446a7ca9a3187fa7e7d)
#         ;
#
#
#
#
#             var circle_5cba537801e38813bc6d7dd9da59a6c8 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot;

# %%
heat = 'map_heat.html'
unemployment = 'map_unemployment.html'

def export_maps(map_file, map_obj):
    map_obj.save(map_file)

# %%
export_maps(unemployment, map_unemployment)
