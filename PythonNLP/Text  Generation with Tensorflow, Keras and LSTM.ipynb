# %% [markdown]
# # Installation and Setup

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
import string
import requests

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >=0:
  print('Select the Runtime > " Change runtime type" menu to enable a GPU accelerator,')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Mar  8 22:48:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total/1e9
print('Your  runtime has {:.1f} BG of Ram\n'.format(ram_gb))

if ram_gb < 20:
  print('Re-select the high-RAM runtime in the Runtime Menu.')
else:
  print('You are using high-RAM runtime!')
# Out:
# Your  runtime has 27.4 BG of Ram
#
# You are using high-RAM runtime!

# %% [markdown]
# # Data Preprocessing

# %%
response = requests.get('http://ocw.mit.edu/ans7870/6/6.006/s08/lecturenotes/files/t8.shakespeare.txt')

# %%
response.text
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# generate a list of strings
data = response.text.split('\n')

# %%
# get a look
data[0]
# Out:
# 'This is the 100th Etext file presented by Project Gutenberg, and'

# %%
# data starts much later
data[253]
# Out:
# '  From fairest creatures we desire increase,'

# %%
data = data[253:]

# %%
data[0]
# Out:
# '  From fairest creatures we desire increase,'

# %%
len(data)
# Out:
# 124204

# %%
# joing all the values now
# this list will be converted to text
data = ' '.join(data)
data
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# remove punctuation
def clean_text(doc):
  tokens = doc.split()
  # remove the punctuation
  table = str.maketrans('','', string.punctuation)
  # list  without punctuation
  tokens = [(w.translate(table)) for w in tokens]
  # get only alpahnumeric chars
  tokens = [word for word  in tokens if word.isalpha()]
  # convert to lower
  tokens = [word.lower() for word in tokens]
  return tokens

# %%
tokens = clean_text(data)
print(tokens[:50])
# Out:
# ['from', 'fairest', 'creatures', 'we', 'desire', 'increase', 'that', 'thereby', 'beautys', 'rose', 'might', 'never', 'die', 'but', 'as', 'the', 'riper', 'should', 'by', 'time', 'decease', 'his', 'tender', 'heir', 'might', 'bear', 'his', 'memory', 'but', 'thou', 'contracted', 'to', 'thine', 'own', 'bright', 'eyes', 'feedst', 'thy', 'lights', 'flame', 'with', 'selfsubstantial', 'fuel', 'making', 'a', 'famine', 'where', 'abundance', 'lies', 'thy']

# %%
# combine the tokens together
len(tokens)
# Out:
# 898199

# %%
# check unique words
len(set(tokens))
# Out:
# 27956

# %% [markdown]
# # Create the Data Sequences
# We will use a particular set of words to predict the next word
#
# Use 50 words per segment to predict the next word

# %%
# set the length as 50 + num_to_predict
num_to_predict = 1

length = 50 + num_to_predict
lines = []

# this range will start from 51
for i in range(length, len(tokens)):
  # seq = 0 to 51 for first sequence
  seq = tokens[i-length:i]
  # join tokens to create a line
  line = ' '.join(seq)
  # append it
  lines.append(line)
  # work with the first 200K words to reduce training
  if i > 200000:
    break

# %%
print(len(lines))
# Out:
# 199951

# %%
# look at a single sequence
lines[0]
# Out:
# 'from fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self'

# %%
tokens[0], tokens[50]
# Out:
# ('from', 'self')

# %%
lines[1]
# Out:
# 'fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thy self thy'

# %%
# shift one token
tokens[1], tokens[51]
# Out:
# ('fairest', 'thy')

# %% [markdown]
# # Tokenization

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Tokenizing and Embedding
# Fit the lines in tokenization then the sequence of words is embedded as an integer.  Each unique word is assigned to an integer.
#
# The sequences will have a list of integer values created by the tokenizer.

# %%
# tokenization
# instantiate a Tokenizer object
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
# sequences

# %%
sequences = np.array(sequences)

# %%
sequences[0]
# Out:
# array([   47,  1408,  1264,    37,   451,  1406,     9,  2766,  1158,
#         1213,   171,   132,   269,    20,    24,     1,  4782,    87,
#           30,    98,  4781,    18,   715,  1263,   171,   211,    18,
#          829,    20,    27,  3807,     4,   214,   121,  1212,   153,
#        13004,    31,  2765,  1847,    16, 13003, 13002,   754,     7,
#         3806,    99,  2430,   466,    31,   307])

# %% [markdown]
# # Create x and y
#
# the first 50 words (x) will be used as an input vector, and the 51st word will be
# sequences is a two dimensional array, rows and columns
# rows a = line of the text, columns, first 50 columns are the x and 51 columns is y

# %%
x, y = sequences[:,:-1],sequences[:,-1]

# %%
x[0]
# Out:
# array([   47,  1408,  1264,    37,   451,  1406,     9,  2766,  1158,
#         1213,   171,   132,   269,    20,    24,     1,  4782,    87,
#           30,    98,  4781,    18,   715,  1263,   171,   211,    18,
#          829,    20,    27,  3807,     4,   214,   121,  1212,   153,
#        13004,    31,  2765,  1847,    16, 13003, 13002,   754,     7,
#         3806,    99,  2430,   466,    31])

# %%
x[0].shape
# Out:
# (50,)

# %%
y[0]
# Out:
# 307

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'i': 3,
#  'to': 4,
#  'of': 5,
#  'you': 6,
#  'a': 7,
#  'my': 8,
#  'that': 9,
#  'in': 10,
#  'is': 11,
#  'not': 12,
#  'it': 13,
#  'for': 14,
#  'me': 15,
#  'with': 16,
#  'he': 17,
#  'his': 18,
#  'your': 19,
#  'but': 20,
#  'be': 21,
#  'this': 22,
#  'have': 23,
#  'as': 24,
#  'him': 25,
#  'so': 26,
#  'thou': 27,
#  'will': 28,
#  'what': 29,
#  'by': 30,
#  'thy': 31,
#  'no': 32,
#  'are': 33,
#  'all': 34,
#  'her': 35,
#  'do': 36,
#  'we': 37,
#  'if': 38,
#  'our': 39,
#  'or': 40,
#  'shall': 41,
#  'thee': 42,
#  'which': 43,
#  'on': 44,
#  'lord': 45,
#  'o': 46,
#  'from': 47,
#  'good': 48,
#  'more': 49,
#  'sir': 50,
#  'was': 51,
#  'they': 52,
#  'well': 53,
#  'at': 54,
#  'would': 55,
#  'when': 56,
#  'now': 57,
#  'come': 58,
#  'love': 59,
#  'th': 60,
#  'than': 61,
#  'am': 62,
#  'then': 63,
#  'she': 64,
#  'their': 65,
#  'them': 66,
#  'how': 67,
#  'enter': 68,
#  'let': 69,
#  'did': 70,
#  'ill': 71,
#  'hath': 72,
#  'one': 73,
#  'us': 74,
#  'know': 75,
#  'first': 76,
#  'make': 77,
#  'had': 78,
#  'like': 79,
#  'here': 80,
#  'upon': 81,
#  'there': 82,
#  'man': 83,
#  'antony': 84,
#  'say': 85,
#  'yet': 86,
#  'should': 87,
#  'may': 88,
#  'king': 89,
#  'go': 90,
#  'were': 91,
#  'ham': 92,
#  'must': 93,
#  'an': 94,
#  'most': 95,
#  'tis': 96,
#  'such': 97,
#  'time': 98,
#  'where': 99,
#  'mine': 100,
#  'why': 101,
#  'see': 102,
#  'give': 103,
#  'out': 104,
#  'can': 105,
#  'too': 106,
#  'some': 107,
#  'speak': 108,
#  'who': 109,
#  'caesar': 110,
#  'take': 111,
#  'rosalind': 112,
#  'cleopatra': 113,
#  'think': 114,
#  'second': 115,
#  'these': 116,
#  'nor': 117,
#  'exeunt': 118,
#  'syracuse': 119,
#  'queen': 120,
#  'own': 121,
#  'made': 122,
#  'heart': 123,
#  'world': 124,
#  'dromio': 125,
#  'very': 126,
#  'antipholus': 127,
#  'much': 128,
#  'tell': 129,
#  'great': 130,
#  'coriolanus': 131,
#  'never': 132,
#  'hear': 133,
#  'art': 134,
#  'up': 135,
#  'though': 136,
#  'before': 137,
#  'menenius': 138,
#  'doth': 139,
#  'cannot': 140,
#  'thus': 141,
#  'being': 142,
#  'scene': 143,
#  'exit': 144,
#  'pray': 145,
#  'life': 146,
#  'could': 147,
#  'true': 148,
#  'again': 149,
#  'away': 150,
#  'parolles': 151,
#  'look': 152,
#  'eyes': 153,
#  'other': 154,
#  'both': 155,
#  'two': 156,
#  'been': 157,
#  'any': 158,
#  'ephesus': 159,
#  'orlando': 160,
#  'death': 161,
#  'imogen': 162,
#  'against': 163,
#  'nothing': 164,
#  'sweet': 165,
#  'rome': 166,
#  'whose': 167,
#  'those': 168,
#  'fair': 169,
#  'nay': 170,
#  'might': 171,
#  'enobarbus': 172,
#  'leave': 173,
#  'father': 174,
#  'hand': 175,
#  'poor': 176,
#  'ay': 177,
#  'noble': 178,
#  'still': 179,
#  'done': 180,
#  'into': 181,
#  'madam': 182,
#  'till': 183,
#  'name': 184,
#  'honour': 185,
#  'ever': 186,
#  'marcius': 187,
#  'old': 188,
#  'find': 189,
#  'long': 190,
#  'better': 191,
#  'gods': 192,
#  'mother': 193,
#  'duke': 194,
#  'sicinius': 195,
#  'many': 196,
#  'men': 197,
#  'son': 198,
#  'part': 199,
#  'soldier': 200,
#  'bertram': 201,
#  'since': 202,
#  'therefore': 203,
#  'way': 204,
#  'even': 205,
#  'master': 206,
#  'posthumus': 207,
#  'wife': 208,
#  'down': 209,
#  'celia': 210,
#  'bear': 211,
#  'helena': 212,
#  'day': 213,
#  'thine': 214,
#  'put': 215,
#  'friends': 216,
#  'home': 217,
#  'comes': 218,
#  'within': 219,
#  'hast': 220,
#  'dear': 221,
#  'heaven': 222,
#  'live': 223,
#  'best': 224,
#  'clown': 225,
#  'gone': 226,
#  'call': 227,
#  'lafeu': 228,
#  'use': 229,
#  'nature': 230,
#  'every': 231,
#  'dead': 232,
#  'lady': 233,
#  'night': 234,
#  'messenger': 235,
#  'only': 236,
#  'service': 237,
#  'has': 238,
#  'brutus': 239,
#  'show': 240,
#  'eye': 241,
#  'cymbeline': 242,
#  'hor': 243,
#  'thing': 244,
#  'does': 245,
#  'hamlet': 246,
#  'fear': 247,
#  'end': 248,
#  'whom': 249,
#  'house': 250,
#  'indeed': 251,
#  'bring': 252,
#  'charmian': 253,
#  'cominius': 254,
#  'cloten': 255,
#  'mistress': 256,
#  'off': 257,
#  'brother': 258,
#  'pisanio': 259,
#  'none': 260,
#  'keep': 261,
#  'himself': 262,
#  'after': 263,
#  'stand': 264,
#  'myself': 265,
#  'god': 266,
#  'blood': 267,
#  'countess': 268,
#  'die': 269,
#  'others': 270,
#  'matter': 271,
#  'servant': 272,
#  'theres': 273,
#  'another': 274,
#  'thats': 275,
#  'aufidius': 276,
#  'hold': 277,
#  'gentleman': 278,
#  'iachimo': 279,
#  'youth': 280,
#  'without': 281,
#  'people': 282,
#  'young': 283,
#  'word': 284,
#  'power': 285,
#  'peace': 286,
#  'rather': 287,
#  'answer': 288,
#  'place': 289,
#  'welcome': 290,
#  'act': 291,
#  'little': 292,
#  'loves': 293,
#  'friend': 294,
#  'set': 295,
#  'adriana': 296,
#  'thought': 297,
#  'hes': 298,
#  'whats': 299,
#  'fortune': 300,
#  'sword': 301,
#  'aside': 302,
#  'together': 303,
#  'once': 304,
#  'words': 305,
#  'touchstone': 306,
#  'self': 307,
#  'makes': 308,
#  'head': 309,
#  'forth': 310,
#  'said': 311,
#  'fool': 312,
#  'pol': 313,
#  'else': 314,
#  'dost': 315,
#  'jaques': 316,
#  'things': 317,
#  'face': 318,
#  'ere': 319,
#  'hope': 320,
#  'please': 321,
#  'play': 322,
#  'heard': 323,
#  'distributed': 324,
#  'lie': 325,
#  'electronic': 326,
#  'copies': 327,
#  'belarius': 328,
#  'full': 329,
#  'farewell': 330,
#  'tongue': 331,
#  'alone': 332,
#  'hence': 333,
#  'lets': 334,
#  'truth': 335,
#  'woman': 336,
#  'grace': 337,
#  'faith': 338,
#  'citizen': 339,
#  'husband': 340,
#  'far': 341,
#  'stay': 342,
#  'seen': 343,
#  'strange': 344,
#  'lords': 345,
#  'marry': 346,
#  'guiderius': 347,
#  'beauty': 348,
#  'hour': 349,
#  'help': 350,
#  'sure': 351,
#  'cause': 352,
#  'follow': 353,
#  'pompey': 354,
#  'roman': 355,
#  'false': 356,
#  'saw': 357,
#  'state': 358,
#  'three': 359,
#  'daughter': 360,
#  'court': 361,
#  'worthy': 362,
#  'yourself': 363,
#  'about': 364,
#  'gentle': 365,
#  'war': 366,
#  'mind': 367,
#  'yours': 368,
#  'thank': 369,
#  'back': 370,
#  'body': 371,
#  'fellow': 372,
#  'less': 373,
#  'mad': 374,
#  'itself': 375,
#  'volumnia': 376,
#  'last': 377,
#  'came': 378,
#  'wilt': 379,
#  'further': 380,
#  'sent': 381,
#  'under': 382,
#  'get': 383,
#  'fall': 384,
#  'william': 385,
#  'lose': 386,
#  'earth': 387,
#  'thoughts': 388,
#  'report': 389,
#  'soul': 390,
#  'ring': 391,
#  'eros': 392,
#  'gave': 393,
#  'enough': 394,
#  'general': 395,
#  'news': 396,
#  'prithee': 397,
#  'arviragus': 398,
#  'times': 399,
#  'bed': 400,
#  'unto': 401,
#  'lost': 402,
#  'third': 403,
#  'between': 404,
#  'laer': 405,
#  'worth': 406,
#  'found': 407,
#  'lay': 408,
#  'diana': 409,
#  'mean': 410,
#  'kind': 411,
#  'believe': 412,
#  'seem': 413,
#  'present': 414,
#  'wars': 415,
#  'pity': 416,
#  'means': 417,
#  'purpose': 418,
#  'ist': 419,
#  'honest': 420,
#  'meet': 421,
#  'each': 422,
#  'rest': 423,
#  'hands': 424,
#  'right': 425,
#  'lepidus': 426,
#  'oph': 427,
#  'praise': 428,
#  'through': 429,
#  'left': 430,
#  'mark': 431,
#  'prove': 432,
#  'gold': 433,
#  'break': 434,
#  'boy': 435,
#  'reason': 436,
#  'business': 437,
#  'sister': 438,
#  'agrippa': 439,
#  'luciana': 440,
#  'shame': 441,
#  'given': 442,
#  'return': 443,
#  'fortunes': 444,
#  'bid': 445,
#  'near': 446,
#  'something': 447,
#  'city': 448,
#  'hate': 449,
#  'neither': 450,
#  'desire': 451,
#  'shalt': 452,
#  'knows': 453,
#  'virtue': 454,
#  'hell': 455,
#  'fathers': 456,
#  'hither': 457,
#  'oliver': 458,
#  'thousand': 459,
#  'fire': 460,
#  'guard': 461,
#  'pardon': 462,
#  'beseech': 463,
#  'country': 464,
#  'menas': 465,
#  'lies': 466,
#  'truly': 467,
#  'send': 468,
#  'seek': 469,
#  'bound': 470,
#  'villain': 471,
#  'proud': 472,
#  'age': 473,
#  'sun': 474,
#  'fight': 475,
#  'sleep': 476,
#  'sea': 477,
#  'common': 478,
#  'serve': 479,
#  'kings': 480,
#  'spirit': 481,
#  'watch': 482,
#  'ears': 483,
#  'reenter': 484,
#  'chain': 485,
#  'new': 486,
#  'work': 487,
#  'sight': 488,
#  'looks': 489,
#  'strong': 490,
#  'wish': 491,
#  'works': 492,
#  'known': 493,
#  'fly': 494,
#  'calld': 495,
#  'tribunes': 496,
#  'note': 497,
#  'oft': 498,
#  'draw': 499,
#  'hearts': 500,
#  'shakespeare': 501,
#  'soldiers': 502,
#  'women': 503,
#  'pleasure': 504,
#  'almost': 505,
#  'thanks': 506,
#  'ho': 507,
#  'lucius': 508,
#  'britain': 509,
#  'horatio': 510,
#  'days': 511,
#  'save': 512,
#  'wit': 513,
#  'captain': 514,
#  'patience': 515,
#  'turn': 516,
#  'charge': 517,
#  'palace': 518,
#  'knave': 519,
#  'yes': 520,
#  'lovd': 521,
#  'officer': 522,
#  'phebe': 523,
#  'laertes': 524,
#  'cold': 525,
#  'same': 526,
#  'ear': 527,
#  'change': 528,
#  'neer': 529,
#  't': 530,
#  'provided': 531,
#  'charges': 532,
#  'fit': 533,
#  'ros': 534,
#  'used': 535,
#  'married': 536,
#  'wherein': 537,
#  'heres': 538,
#  'took': 539,
#  'swear': 540,
#  'project': 541,
#  'egypt': 542,
#  'octavia': 543,
#  'silvius': 544,
#  'light': 545,
#  'past': 546,
#  'heavens': 547,
#  'air': 548,
#  'whilst': 549,
#  'dare': 550,
#  'while': 551,
#  'tears': 552,
#  'told': 553,
#  'worse': 554,
#  'remember': 555,
#  'personal': 556,
#  'command': 557,
#  'ourselves': 558,
#  'iras': 559,
#  'majesty': 560,
#  'oer': 561,
#  'lack': 562,
#  'care': 563,
#  'breath': 564,
#  'tomorrow': 565,
#  'action': 566,
#  'late': 567,
#  'complete': 568,
#  'college': 569,
#  'machine': 570,
#  'distribution': 571,
#  'ask': 572,
#  'letter': 573,
#  'joy': 574,
#  'either': 575,
#  'hard': 576,
#  'version': 577,
#  'copyright': 578,
#  'library': 579,
#  'inc': 580,
#  'gutenberg': 581,
#  'etext': 582,
#  'illinois': 583,
#  'benedictine': 584,
#  'permission': 585,
#  'readable': 586,
#  'commercially': 587,
#  'prohibited': 588,
#  'commercial': 589,
#  'includes': 590,
#  'download': 591,
#  'membership': 592,
#  'spoke': 593,
#  'forest': 594,
#  'lartius': 595,
#  'high': 596,
#  'grave': 597,
#  'free': 598,
#  'hours': 599,
#  'widow': 600,
#  'themselves': 601,
#  'wind': 602,
#  'half': 603,
#  'trust': 604,
#  'brought': 605,
#  'grief': 606,
#  'land': 607,
#  'says': 608,
#  'twas': 609,
#  'met': 610,
#  'angelo': 611,
#  'count': 612,
#  'sing': 613,
#  'thyself': 614,
#  'mans': 615,
#  'sense': 616,
#  'sit': 617,
#  'kill': 618,
#  'flourish': 619,
#  'mar': 620,
#  'voices': 621,
#  'certain': 622,
#  'enemy': 623,
#  'int': 624,
#  'youll': 625,
#  'boys': 626,
#  'tonight': 627,
#  'dolabella': 628,
#  'caesars': 629,
#  'eat': 630,
#  'having': 631,
#  'question': 632,
#  'read': 633,
#  'write': 634,
#  'duty': 635,
#  'didst': 636,
#  'comfort': 637,
#  'years': 638,
#  'goes': 639,
#  'born': 640,
#  'drink': 641,
#  'masters': 642,
#  'money': 643,
#  'virgilia': 644,
#  'lives': 645,
#  'wear': 646,
#  'sake': 647,
#  'horse': 648,
#  'ladies': 649,
#  'sound': 650,
#  'dot': 651,
#  'gives': 652,
#  'music': 653,
#  'weep': 654,
#  'grow': 655,
#  'wherefore': 656,
#  'haste': 657,
#  'holy': 658,
#  'slave': 659,
#  'voice': 660,
#  'ghost': 661,
#  'gentlemen': 662,
#  'ont': 663,
#  'shes': 664,
#  'senior': 665,
#  'polonius': 666,
#  'content': 667,
#  'happy': 668,
#  'rich': 669,
#  'fault': 670,
#  'lest': 671,
#  'today': 672,
#  'cry': 673,
#  'ground': 674,
#  'knew': 675,
#  'foul': 676,
#  'attendants': 677,
#  'ii': 678,
#  'drum': 679,
#  'iii': 680,
#  'company': 681,
#  'unless': 682,
#  'behind': 683,
#  'deny': 684,
#  'black': 685,
#  'point': 686,
#  'judgment': 687,
#  'bad': 688,
#  'maid': 689,
#  'withal': 690,
#  'speech': 691,
#  'fare': 692,
#  'alexas': 693,
#  'brothers': 694,
#  'corin': 695,
#  'ten': 696,
#  'brave': 697,
#  'often': 698,
#  'wrong': 699,
#  'appear': 700,
#  'pretty': 701,
#  'foot': 702,
#  'soon': 703,
#  'need': 704,
#  'run': 705,
#  'alas': 706,
#  'try': 707,
#  'doubt': 708,
#  'sons': 709,
#  'tot': 710,
#  'beat': 711,
#  'arms': 712,
#  'army': 713,
#  'audrey': 714,
#  'tender': 715,
#  'child': 716,
#  'pay': 717,
#  'gainst': 718,
#  'behold': 719,
#  'coming': 720,
#  'wouldst': 721,
#  'strength': 722,
#  'sorrow': 723,
#  'remain': 724,
#  'stands': 725,
#  'cut': 726,
#  'already': 727,
#  'yield': 728,
#  'soft': 729,
#  'begin': 730,
#  'lips': 731,
#  'suit': 732,
#  'madness': 733,
#  'citizens': 734,
#  'fetch': 735,
#  'arm': 736,
#  'frederick': 737,
#  'bloody': 738,
#  'gracious': 739,
#  'course': 740,
#  'sad': 741,
#  'whether': 742,
#  'heavy': 743,
#  'attend': 744,
#  'straight': 745,
#  'side': 746,
#  'pass': 747,
#  'brain': 748,
#  'sick': 749,
#  'whole': 750,
#  'buy': 751,
#  'france': 752,
#  'merchant': 753,
#  'making': 754,
#  'living': 755,
#  'mortal': 756,
#  'longer': 757,
#  'fine': 758,
#  'woe': 759,
#  'deeds': 760,
#  'faults': 761,
#  'needs': 762,
#  'hang': 763,
#  'sin': 764,
#  'colour': 765,
#  'seems': 766,
#  'receive': 767,
#  'twere': 768,
#  'letters': 769,
#  'banishd': 770,
#  'noise': 771,
#  'merry': 772,
#  'door': 773,
#  'caius': 774,
#  'town': 775,
#  'senator': 776,
#  'consul': 777,
#  'guildenstern': 778,
#  'fast': 779,
#  'takes': 780,
#  'knowledge': 781,
#  'passion': 782,
#  'pride': 783,
#  'pale': 784,
#  'excellent': 785,
#  'lead': 786,
#  'offence': 787,
#  'going': 788,
#  'five': 789,
#  'got': 790,
#  'hearing': 791,
#  'sport': 792,
#  'kiss': 793,
#  'devil': 794,
#  'talk': 795,
#  'stood': 796,
#  'deed': 797,
#  'lordship': 798,
#  'iv': 799,
#  'soothsayer': 800,
#  'person': 801,
#  'adam': 802,
#  'ophelia': 803,
#  'guil': 804,
#  'form': 805,
#  'calls': 806,
#  'parts': 807,
#  'ah': 808,
#  'grant': 809,
#  'glad': 810,
#  'favour': 811,
#  'base': 812,
#  'greater': 813,
#  'dull': 814,
#  'flesh': 815,
#  'thence': 816,
#  'cheek': 817,
#  'above': 818,
#  'fools': 819,
#  'revenge': 820,
#  'touch': 821,
#  'rousillon': 822,
#  'royal': 823,
#  'highness': 824,
#  'honours': 825,
#  'dinner': 826,
#  'hark': 827,
#  'maecenas': 828,
#  'memory': 829,
#  'shouldst': 830,
#  'rage': 831,
#  'chance': 832,
#  'fell': 833,
#  'witness': 834,
#  'confess': 835,
#  'ye': 836,
#  'water': 837,
#  'move': 838,
#  'cast': 839,
#  'case': 840,
#  'win': 841,
#  'gates': 842,
#  'wise': 843,
#  'besides': 844,
#  'mercy': 845,
#  'danger': 846,
#  'warrant': 847,
#  'em': 848,
#  'lookd': 849,
#  'shepherd': 850,
#  'song': 851,
#  'kept': 852,
#  'shows': 853,
#  'fashion': 854,
#  'loss': 855,
#  'blame': 856,
#  'went': 857,
#  'adieu': 858,
#  'suffer': 859,
#  'wonder': 860,
#  'struck': 861,
#  'next': 862,
#  'poison': 863,
#  'herself': 864,
#  'understand': 865,
#  'taen': 866,
#  'camp': 867,
#  'romans': 868,
#  'aegeon': 869,
#  'corioli': 870,
#  'rosencrantz': 871,
#  'field': 872,
#  'dies': 873,
#  'canst': 874,
#  'mayst': 875,
#  'beard': 876,
#  'shake': 877,
#  'died': 878,
#  'because': 879,
#  'motion': 880,
#  'quick': 881,
#  'marriage': 882,
#  'over': 883,
#  'dispatch': 884,
#  'thither': 885,
#  'honesty': 886,
#  'beg': 887,
#  'obey': 888,
#  'presently': 889,
#  'along': 890,
#  'alexandria': 891,
#  'fie': 892,
#  'wounds': 893,
#  'abbess': 894,
#  'osr': 895,
#  'deep': 896,
#  'lend': 897,
#  'folly': 898,
#  'methinks': 899,
#  'sorry': 900,
#  'want': 901,
#  'respect': 902,
#  'morning': 903,
#  'promise': 904,
#  'yea': 905,
#  'hers': 906,
#  'four': 907,
#  'force': 908,
#  'tongues': 909,
#  'hurt': 910,
#  'fort': 911,
#  'office': 912,
#  'crown': 913,
#  'throw': 914,
#  'taken': 915,
#  'laid': 916,
#  'neck': 917,
#  'feed': 918,
#  'sworn': 919,
#  'twenty': 920,
#  'monsieur': 921,
#  'quoth': 922,
#  'strike': 923,
#  'le': 924,
#  'v': 925,
#  'ready': 926,
#  'senators': 927,
#  'players': 928,
#  'view': 929,
#  'treasure': 930,
#  'excuse': 931,
#  'natures': 932,
#  'leaves': 933,
#  'pluck': 934,
#  'moon': 935,
#  'writ': 936,
#  'public': 937,
#  'precious': 938,
#  'anon': 939,
#  'knowst': 940,
#  'health': 941,
#  'feast': 942,
#  'whence': 943,
#  'choose': 944,
#  'proceed': 945,
#  'spirits': 946,
#  'walk': 947,
#  'become': 948,
#  'valiant': 949,
#  'awhile': 950,
#  'speaks': 951,
#  'ha': 952,
#  'plebeians': 953,
#  'charles': 954,
#  'valeria': 955,
#  'denmark': 956,
#  'elsinore': 957,
#  'held': 958,
#  'sings': 959,
#  'wisdom': 960,
#  'brief': 961,
#  'drawn': 962,
#  'short': 963,
#  'hot': 964,
#  'souls': 965,
#  'forgot': 966,
#  'scorn': 967,
#  'sovereign': 968,
#  'hadst': 969,
#  'melancholy': 970,
#  'vile': 971,
#  'children': 972,
#  'story': 973,
#  'dream': 974,
#  'hair': 975,
#  'courtier': 976,
#  'fought': 977,
#  'sirrah': 978,
#  'demand': 979,
#  'honourable': 980,
#  'laugh': 981,
#  'ass': 982,
#  'wast': 983,
#  'whither': 984,
#  'labour': 985,
#  'wheres': 986,
#  'jupiter': 987,
#  'gaoler': 988,
#  'beau': 989,
#  'england': 990,
#  'volsces': 991,
#  'cornelius': 992,
#  'mothers': 993,
#  'single': 994,
#  'grows': 995,
#  'verse': 996,
#  'rare': 997,
#  'breast': 998,
#  'therein': 999,
#  'loving': 1000,
#  ...}

# %%
# length of total vocabulary
len(tokenizer.word_index)
# Out:
# 13008

# %%
vocab_size = len(tokenizer.word_index) + 1 # add 1 for zero indexing

# %%
vocab_size
# Out:
# 13009

# %%
# in original text, total number of unique words
# after data cleaning more condensed  to 13009
len(set(tokens))
# Out:
# 27956

# %%
y = to_categorical(y, num_classes=vocab_size)

# %%
x.shape[1]
# Out:
# 50

# %%
seq_length = x.shape[1]
seq_length
# Out:
# 50

# %% [markdown]
# # Build the LSTM Model

# %%
model = Sequential()

# First embedding layer
model.add(Embedding(input_dim=vocab_size, output_dim=50, input_length=seq_length))

# First LSTM layer
model.add(LSTM(units=100, return_sequences=True))

# Second LSTM layer
model.add(LSTM(units=100))

# Dense layer
model.add(Dense(units=100, activation='relu'))

# final layer
model.add(Dense(units=vocab_size, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 50)            650450
# _________________________________________________________________
# lstm (LSTM)                  (None, 50, 100)           60400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 100)               10100
# _________________________________________________________________
# dense_1 (Dense)              (None, 13009)             1313909
# =================================================================
# Total params: 2,115,259
# Trainable params: 2,115,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#train the model
model.fit(x,y, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 40s 28ms/step - loss: 7.1969 - accuracy: 0.0277
# Epoch 2/100
# 782/782 [==============================] - 22s 28ms/step - loss: 6.5371 - accuracy: 0.0411
# Epoch 3/100
# 782/782 [==============================] - 22s 28ms/step - loss: 6.3523 - accuracy: 0.0528
# Epoch 4/100
# 782/782 [==============================] - 22s 28ms/step - loss: 6.1492 - accuracy: 0.0702
# Epoch 5/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.9785 - accuracy: 0.0838
# Epoch 6/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.8425 - accuracy: 0.0929
# Epoch 7/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.7422 - accuracy: 0.0993
# Epoch 8/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.6437 - accuracy: 0.1029
# Epoch 9/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.5726 - accuracy: 0.1049
# Epoch 10/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.4968 - accuracy: 0.1093
# Epoch 11/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.4203 - accuracy: 0.1116
# Epoch 12/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.3399 - accuracy: 0.1152
# Epoch 13/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.2722 - accuracy: 0.1169
# Epoch 14/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.1969 - accuracy: 0.1184
# Epoch 15/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.1443 - accuracy: 0.1205
# Epoch 16/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.0836 - accuracy: 0.1229
# Epoch 17/100
# 782/782 [==============================] - 22s 28ms/step - loss: 5.0176 - accuracy: 0.1245
# Epoch 18/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.9552 - accuracy: 0.1264
# Epoch 19/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.9030 - accuracy: 0.1297
# Epoch 20/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.8442 - accuracy: 0.1346
# Epoch 21/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.7921 - accuracy: 0.1386
# Epoch 22/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.7517 - accuracy: 0.1410
# Epoch 23/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.6998 - accuracy: 0.1453
# Epoch 24/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.6611 - accuracy: 0.1482
# Epoch 25/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.6233 - accuracy: 0.1525
# Epoch 26/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.5766 - accuracy: 0.1574
# Epoch 27/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.5392 - accuracy: 0.1608
# Epoch 28/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.5084 - accuracy: 0.1643
# Epoch 29/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.4782 - accuracy: 0.1675
# Epoch 30/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.4413 - accuracy: 0.1716
# Epoch 31/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.4151 - accuracy: 0.1739
# Epoch 32/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.3673 - accuracy: 0.1782
# Epoch 33/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.3467 - accuracy: 0.1802
# Epoch 34/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.3175 - accuracy: 0.1839
# Epoch 35/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.2917 - accuracy: 0.1870
# Epoch 36/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.2647 - accuracy: 0.1911
# Epoch 37/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.2273 - accuracy: 0.1939
# Epoch 38/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.2107 - accuracy: 0.1969
# Epoch 39/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.1892 - accuracy: 0.1982
# Epoch 40/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.1598 - accuracy: 0.2028
# Epoch 41/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.1281 - accuracy: 0.2067
# Epoch 42/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.1134 - accuracy: 0.2079
# Epoch 43/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.0785 - accuracy: 0.2114
# Epoch 44/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.0702 - accuracy: 0.2139
# Epoch 45/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.0331 - accuracy: 0.2174
# Epoch 46/100
# 782/782 [==============================] - 22s 28ms/step - loss: 4.0083 - accuracy: 0.2212
# Epoch 47/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.9865 - accuracy: 0.2234
# Epoch 48/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.9719 - accuracy: 0.2254
# Epoch 49/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.9437 - accuracy: 0.2288
# Epoch 50/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.9285 - accuracy: 0.2317
# Epoch 51/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.9077 - accuracy: 0.2336
# Epoch 52/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.8858 - accuracy: 0.2381
# Epoch 53/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.8607 - accuracy: 0.2398
# Epoch 54/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.8480 - accuracy: 0.2416
# Epoch 55/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.8285 - accuracy: 0.2434
# Epoch 56/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.8111 - accuracy: 0.2467
# Epoch 57/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7859 - accuracy: 0.2502
# Epoch 58/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7645 - accuracy: 0.2552
# Epoch 59/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7492 - accuracy: 0.2550
# Epoch 60/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7373 - accuracy: 0.2556
# Epoch 61/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7122 - accuracy: 0.2604
# Epoch 62/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.7029 - accuracy: 0.2610
# Epoch 63/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6762 - accuracy: 0.2645
# Epoch 64/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6508 - accuracy: 0.2688
# Epoch 65/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6470 - accuracy: 0.2683
# Epoch 66/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6225 - accuracy: 0.2712
# Epoch 67/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6116 - accuracy: 0.2746
# Epoch 68/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.6012 - accuracy: 0.2756
# Epoch 69/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.5829 - accuracy: 0.2782
# Epoch 70/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.5603 - accuracy: 0.2803
# Epoch 71/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.5432 - accuracy: 0.2848
# Epoch 72/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.5359 - accuracy: 0.2837
# Epoch 73/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.5071 - accuracy: 0.2901
# Epoch 74/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4935 - accuracy: 0.2907
# Epoch 75/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4823 - accuracy: 0.2910
# Epoch 76/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4705 - accuracy: 0.2933
# Epoch 77/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4496 - accuracy: 0.2972
# Epoch 78/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4311 - accuracy: 0.3003
# Epoch 79/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4226 - accuracy: 0.3028
# Epoch 80/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.4072 - accuracy: 0.3014
# Epoch 81/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3860 - accuracy: 0.3074
# Epoch 82/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3772 - accuracy: 0.3063
# Epoch 83/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3742 - accuracy: 0.3082
# Epoch 84/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3595 - accuracy: 0.3098
# Epoch 85/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3358 - accuracy: 0.3140
# Epoch 86/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3147 - accuracy: 0.3175
# Epoch 87/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.3041 - accuracy: 0.3173
# Epoch 88/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2985 - accuracy: 0.3167
# Epoch 89/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2816 - accuracy: 0.3219
# Epoch 90/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2570 - accuracy: 0.3243
# Epoch 91/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2631 - accuracy: 0.3258
# Epoch 92/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2446 - accuracy: 0.3265
# Epoch 93/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2320 - accuracy: 0.3298
# Epoch 94/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.2101 - accuracy: 0.3327
# Epoch 95/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1966 - accuracy: 0.3363
# Epoch 96/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1797 - accuracy: 0.3375
# Epoch 97/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1689 - accuracy: 0.3407
# Epoch 98/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1557 - accuracy: 0.3404
# Epoch 99/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1461 - accuracy: 0.3432
# Epoch 100/100
# 782/782 [==============================] - 22s 28ms/step - loss: 3.1428 - accuracy: 0.3423

# %%
# create a seed line
lines[12343]
# Out:
# 'home of love if i have ranged like him that travels i return again just to the time not with the time exchanged so that my self bring water for my stain never believe though in my nature reigned all frailties that besiege all kinds of blood that it could so'

# %%
seed_text = lines[12343]

# %%
# define a function for generation

def generate_text_seq(model, tokenizer, text_seq_length, seed_text, n_words):
  text = []

  for _ in range(n_words):
    encoded = tokenizer.texts_to_sequences([seed_text])[0] # zeorth dimension of the array
    encoded = pad_sequences([encoded], maxlen = text_seq_length, truncating = 'pre')

    y_predict = model.predict_classes(encoded)

    predicted_word = ''
    for word, index in tokenizer.word_index.items():
      if index == y_predict:
        predicted_word = word
        break
    seed_text = seed_text + ' ' + predicted_word
    text.append(predicted_word)
  return ' '.join(text)

# %%
generate_text_seq(model, tokenizer, seq_length, seed_text, 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 'preposterously be stained to leave for the nonce octavia twixt'
